# %%
import numpy as np 
import pandas as pd
import matplotlib as mpl

# %%
df=pd.read_csv("/kaggle/input/datasets/fatuzahra/irisiris/iris.csv")

# %%
df.head

# %%
print(df["sepal_width"].head())

# %%
print(df[['sepal_length','petal_length']].head())

# %%
setosa=df[df['species']=='setosa']
print(setosa)

# %%
setosa=df[df['sepal_length']<5.0]
print(setosa)

# %%
mean_sepal_length=df['sepal_length'].mean()
print(mean_sepal_length)

# %%
median_petal_width=df['petal_width'].median()
print(median_petal_width)

# %%
std_petal_length=df['petal_length'].std()
print(f"{std_petal_length:.2f}")

# %%
df.groupby("species")["petal_width"].mean()
